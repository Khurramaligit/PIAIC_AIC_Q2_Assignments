# %%
import numpy as np
import pandas as pd

# %%
Str = pd.read_csv('D:\PIAIC_AIC_Q2_Assignments\Dataset\Compresive_Strength_Concrete_DataSet\compresive_strength_concrete.csv')

# %%
Str.head(10)
# Out:
#    Cement (component 1)(kg in a m^3 mixture)  \
# 0                                      540.0
# 1                                      540.0
# 2                                      332.5
# 3                                      332.5
# 4                                      198.6
# 5                                      266.0
# 6                                      380.0
# 7                                      380.0
# 8                                      266.0
# 9                                      475.0
#
#    Blast Furnace Slag (component 2)(kg in a m^3 mixture)  \
# 0                                                0.0
# 1                                                0.0
# 2                                              142.5
# 3                                              142.5
# 4                                              132.4
# 5                                              114.0
# 6                                               95.0
# ...

# %%
df = pd.DataFrame(Str)

#detecting missing values
df2 = df.isnull()

print(df2)
# Out:
#       Cement (component 1)(kg in a m^3 mixture)  \
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
# ...                                         ...
# 1025                                      False
# 1026                                      False
# 1027                                      False
# 1028                                      False
# 1029                                      False
#
#       Blast Furnace Slag (component 2)(kg in a m^3 mixture)  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...
